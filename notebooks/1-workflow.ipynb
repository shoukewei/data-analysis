# %% [markdown]
# # The Data Analysis Workflow

# %% [markdown]
# #### Verifying the Installation

# %%
import numpy as np
import pandas as pd
import polars as pl

print("Environment ready!")
# Out:
# Running cells with 'Python 3.14.2' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/shouk/AppData/Roaming/uv/python/cpython-3.14.2-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #### Basic PySpark Setup

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("test").getOrCreate()
spark.range(5).show()
# Out:
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+
